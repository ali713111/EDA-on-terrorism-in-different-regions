# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Load and Read Data
filepath =  r'/content/globalterrorismdb_0718dist.csv'

# %%
terrorism_df = pd.read_csv(r'/content/globalterrorismdb_0718dist.csv', encoding='latin1')

# %%
terrorism_df.shape
# Out:
# (72968, 135)

# %%
terrorism_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terrorism_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
 terrorism_df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    72850
#               ...
# INT_LOG           0
# INT_IDEO          0
# INT_MISC          0
# INT_ANY           0
# related       64876
# Length: 135, dtype: int64

# %%
 terrorism_df.isna().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    72850
#               ...
# INT_LOG           0
# INT_IDEO          0
# INT_MISC          0
# INT_ANY           0
# related       64876
# Length: 135, dtype: int64

# %%
terrorism_df.columns.nunique()
# Out:
# 135

# %%
terrorism_df=terrorism_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'})

# %%
terrorism_df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_25, *['eventid'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_26, *['Month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_27, *['Day'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_28, *['country'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_29, *['eventid'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_30, *['Month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_31, *['Day'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_32, *['country'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_33, *['Country'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_34, *['Region'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_35, *['State'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_36, *['City'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_37, *[[['eventid', 'Month'], ['Month', 'Day'], ['Day', 'country'], ['country', 'region']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_38, *['Country', 'Region'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_39, *['Region', 'State'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_40, *['State', 'City'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_41, *['City', 'Attack_type'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_42, *['eventid', 'Country'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_43, *['eventid', 'Region'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_44, *['eventid', 'State'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_45, *['eventid', 'City'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_46, *['eventid', 'Month', 'Country'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_47, *['eventid', 'Month', 'Region'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_48, *['eventid', 'Month', 'State'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_49, *['eventid', 'Month', 'City'], **{})
# chart

# %%
#  NaN values in Target_subtype column as Others

# %%
terrorism_df['Target_subtype'] = terrorism_df['Target_subtype'].fillna('others')

# %% [markdown]
# NaN values in the State column as Unknown

# %%
terrorism_df['State'] = terrorism_df['State'].fillna('Unknown')

# %%
 terrorism_df['State'].fillna('Unknown')
# Out:
# 0                                  unknown
# 1                                  Federal
# 2                                   Tarlac
# 3                                   Attica
# 4                                  Fukouka
#                        ...
# 72963                                Beqaa
# 72964    Greater Skopje (Special Division)
# 72965                             Northern
# 72966                            West Bank
# 72967                  Chechnya (Republic)
# Name: State, Length: 72968, dtype: object

# %% [markdown]
# NaN values in the city column as Unknown

# %%
terrorism_df['City'].fillna('Unknown')
# Out:
# 0        Santo Domingo
# 1          Mexico city
# 2              Unknown
# 3               Athens
# 4              Fukouka
#              ...
# 72963          Baalbek
# 72964           Skopje
# 72965            Pabbo
# 72966           Halhul
# 72967           Grozny
# Name: City, Length: 72968, dtype: object

# %%
terrorism_df.shape
# Out:
# (72968, 135)

# %%
terrorism_df=terrorism_df[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
terrorism_df
# Out:
#        Year  Month  Day                   Country  \
# 0      1970      7    2        Dominican Republic
# 1      1970      0    0                    Mexico
# 2      1970      1    0               Philippines
# 3      1970      1    0                    Greece
# 4      1970      1    0                     Japan
# ...     ...    ...  ...                       ...
# 72963  2001      8   27                   Lebanon
# 72964  2001      8   27                 Macedonia
# 72965  2001      8   27                    Uganda
# 72966  2001      8   27  West Bank and Gaza Strip
# 72967  2001      8   27                    Russia
#
#                             Region                              State  \
# 0      Central America & Caribbean                            unknown
# 1                    North America                            Federal
# 2                   Southeast Asia                             Tarlac
# 3                   Western Europe                             Attica
# 4                        East Asia                            Fukouka
# ...                            ...                                ...
# 72963   Middle East & North Africa                              Beqaa
# 72964               Eastern Europe  Greater Skopje (Special Division)
# 72965           Sub-Saharan Africa                           Northern
# 72966   Middle East & North Africa                          West Bank
# 72967               Eastern Europe                Chechnya (Republic)
#
#                 City                     Attack_type  \
# 0      Santo Domingo                   Assassination
# 1        Mexico city     Hostage Taking (Kidnapping)
# 2            Unknown                   Assassination
# 3             Athens               Bombing/Explosion
# 4            Fukouka  Facility/Infrastructure Attack
# ...              ...                             ...
# 72963        Baalbek               Bombing/Explosion
# 72964         Skopje               Bombing/Explosion
# 72965          Pabbo                   Armed Assault
# 72966         Halhul                   Armed Assault
# 72967         Grozny                   Armed Assault
#
#                        Target_type  \
# 0      Private Citizens & Property
# 1          Government (Diplomatic)
# 2              Journalists & Media
# 3          Government (Diplomatic)
# 4          Government (Diplomatic)
# ...                            ...
# 72963         Food or Water Supply
# 72964  Private Citizens & Property
# 72965               Transportation
# 72966               Transportation
# 72967                       Police
#
#                                           Target_subtype  \
# 0                                         Named Civilian
# 1      Diplomatic Personnel (outside of embassy, cons...
# 2                        Radio Journalist/Staff/Facility
# 3                                      Embassy/Consulate
# 4                                      Embassy/Consulate
# ...                                                  ...
# 72963                                       Water Supply
# 72964                           Marketplace/Plaza/Square
# 72965                           Bus (excluding tourists)
# 72966                           Bus (excluding tourists)
# 72967     Police Patrol (including vehicles and convoys)
#
#                                 Gang_name Weapon_type
# 0                                  MANO-D     Unknown
# 1      23rd of September Communist League     Unknown
# 2                                 Unknown     Unknown
# 3                                 Unknown  Explosives
# 4                                 Unknown  Incendiary
# ...                                   ...         ...
# 72963                             Unknown  Explosives
# 72964                             Unknown  Explosives
# 72965        Lord's Resistance Army (LRA)    Firearms
# 72966                             Unknown    Firearms
# 72967                      Chechen Rebels    Firearms
#
# [72968 rows x 12 columns]

# %% [markdown]
# NaN values in Target_subtype column as Others

# %%
terrorism_df['Target_subtype'].fillna('others')
# Out:
# 0                                           Named Civilian
# 1        Diplomatic Personnel (outside of embassy, cons...
# 2                          Radio Journalist/Staff/Facility
# 3                                        Embassy/Consulate
# 4                                        Embassy/Consulate
#                                ...
# 72963                                         Water Supply
# 72964                             Marketplace/Plaza/Square
# 72965                             Bus (excluding tourists)
# 72966                             Bus (excluding tourists)
# 72967       Police Patrol (including vehicles and convoys)
# Name: Target_subtype, Length: 72968, dtype: object

# %% [markdown]
# To make it simpler replace it with Vehicle

# %%
terrorism_df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
terrorism_df
# Out:
#        Year  Month  Day                   Country  \
# 0      1970      7    2        Dominican Republic
# 1      1970      0    0                    Mexico
# 2      1970      1    0               Philippines
# 3      1970      1    0                    Greece
# 4      1970      1    0                     Japan
# ...     ...    ...  ...                       ...
# 72963  2001      8   27                   Lebanon
# 72964  2001      8   27                 Macedonia
# 72965  2001      8   27                    Uganda
# 72966  2001      8   27  West Bank and Gaza Strip
# 72967  2001      8   27                    Russia
#
#                             Region                              State  \
# 0      Central America & Caribbean                            unknown
# 1                    North America                            Federal
# 2                   Southeast Asia                             Tarlac
# 3                   Western Europe                             Attica
# 4                        East Asia                            Fukouka
# ...                            ...                                ...
# 72963   Middle East & North Africa                              Beqaa
# 72964               Eastern Europe  Greater Skopje (Special Division)
# 72965           Sub-Saharan Africa                           Northern
# 72966   Middle East & North Africa                          West Bank
# 72967               Eastern Europe                Chechnya (Republic)
#
#                 City                     Attack_type  \
# 0      Santo Domingo                   Assassination
# 1        Mexico city     Hostage Taking (Kidnapping)
# 2            Unknown                   Assassination
# 3             Athens               Bombing/Explosion
# 4            Fukouka  Facility/Infrastructure Attack
# ...              ...                             ...
# 72963        Baalbek               Bombing/Explosion
# 72964         Skopje               Bombing/Explosion
# 72965          Pabbo                   Armed Assault
# 72966         Halhul                   Armed Assault
# 72967         Grozny                   Armed Assault
#
#                        Target_type  \
# 0      Private Citizens & Property
# 1          Government (Diplomatic)
# 2              Journalists & Media
# 3          Government (Diplomatic)
# 4          Government (Diplomatic)
# ...                            ...
# 72963         Food or Water Supply
# 72964  Private Citizens & Property
# 72965               Transportation
# 72966               Transportation
# 72967                       Police
#
#                                           Target_subtype  \
# 0                                         Named Civilian
# 1      Diplomatic Personnel (outside of embassy, cons...
# 2                        Radio Journalist/Staff/Facility
# 3                                      Embassy/Consulate
# 4                                      Embassy/Consulate
# ...                                                  ...
# 72963                                       Water Supply
# 72964                           Marketplace/Plaza/Square
# 72965                           Bus (excluding tourists)
# 72966                           Bus (excluding tourists)
# 72967     Police Patrol (including vehicles and convoys)
#
#                                 Gang_name Weapon_type
# 0                                  MANO-D     Unknown
# 1      23rd of September Communist League     Unknown
# 2                                 Unknown     Unknown
# 3                                 Unknown  Explosives
# 4                                 Unknown  Incendiary
# ...                                   ...         ...
# 72963                             Unknown  Explosives
# 72964                             Unknown  Explosives
# 72965        Lord's Resistance Army (LRA)    Firearms
# 72966                             Unknown    Firearms
# 72967                      Chechen Rebels    Firearms
#
# [72968 rows x 12 columns]

# %%
terrorism_df.shape
# Out:
# (72968, 12)

# %%
terrorism_df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_type       0
# Target_type       0
# Target_subtype    0
# Gang_name         0
# Weapon_type       0
# dtype: int64

# %%
terrorism_df.head(10)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
# 5  1970      1    1       United States                North America
# 6  1970      1    2             Uruguay                South America
# 7  1970      1    2       United States                North America
# 8  1970      1    2       United States                North America
# 9  1970      1    3       United States                North America
#
#         State           City                     Attack_type  \
# 0     unknown  Santo Domingo                   Assassination
# 1     Federal    Mexico city     Hostage Taking (Kidnapping)
# 2      Tarlac        Unknown                   Assassination
# 3      Attica         Athens               Bombing/Explosion
# 4     Fukouka        Fukouka  Facility/Infrastructure Attack
# 5    Illinois          Cairo                   Armed Assault
# 6  Montevideo     Montevideo                   Assassination
# 7  California        Oakland               Bombing/Explosion
# 8   Wisconsin        Madison  Facility/Infrastructure Attack
# 9   Wisconsin        Madison  Facility/Infrastructure Attack
#
#                    Target_type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                       Target_subtype  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                             Gang_name Weapon_type
# 0                              MANO-D     Unknown
# 1  23rd of September Communist League     Unknown
# 2                             Unknown     Unknown
# 3                             Unknown  Explosives
# 4                             Unknown  Incendiary
# 5                  Black Nationalists    Firearms
# 6                 Tupamaros (Uruguay)    Firearms
# 7                             Unknown  Explosives
# 8                     New Year's Gang  Incendiary
# 9                     New Year's Gang  Incendiary

# %%
terrorism_df.columns.unique()
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %%
terrorism_df.columns.nunique()
# Out:
# 12

# %%
terrorism_df['Country'].nunique()
# Out:
# 199

# %%
terrorism_df['Region'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
terrorism_df['Attack_type'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
terrorism_df['Target_type'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
terrorism_df['Gang_name'].unique()
# Out:
# array(['MANO-D', '23rd of September Communist League', 'Unknown', ...,
#        'Albanian National Army (ANA)',
#        'Popular Army Vanguards- Battalions of Return',
#        'South Londonderry Volunteers (SLV)'], dtype=object)

# %%
terrorism_df['Gang_name'].nunique()
# Out:
# 2435

# %%
terrorism_df['Weapon_type'].unique()
# Out:
# array(['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment', 'Vehicle', 'Fake Weapons',
#        'Radiological', 'Other', 'Biological'], dtype=object)

# %%
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72968 entries, 0 to 72967
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            72968 non-null  int64
#  1   Month           72968 non-null  int64
#  2   Day             72968 non-null  int64
#  3   Country         72968 non-null  object
#  4   Region          72968 non-null  object
#  5   State           72968 non-null  object
#  6   City            72968 non-null  object
#  7   Attack_type     72968 non-null  object
#  8   Target_type     72968 non-null  object
#  9   Target_subtype  72968 non-null  object
#  10  Gang_name       72968 non-null  object
#  11  Weapon_type     72968 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 6.7+ MB

# %%
terrorism_df.describe()
# Out:
#                Year         Month           Day
# count  72968.000000  72968.000000  72968.000000
# mean    1987.814343      6.457379     15.373547
# std        7.094515      3.388689      8.801382
# min     1970.000000      0.000000      0.000000
# 25%     1983.000000      4.000000      8.000000
# 50%     1988.000000      6.000000     15.000000
# 75%     1994.000000      9.000000     23.000000
# max     2001.000000     12.000000     31.000000

# %%
terrorism_df['Country'].value_counts().head(10)
# Out:
# Colombia          6471
# Peru              6029
# El Salvador       5320
# United Kingdom    4308
# India             3387
# Spain             3004
# Turkey            2540
# United States     2413
# France            2289
# Chile             2272
# Name: Country, dtype: int64

# %%
terrorism_df['Region'].value_counts().head(10)
# Out:
# South America                  16768
# Western Europe                 13873
# Central America & Caribbean    10277
# Middle East & North Africa      9901
# South Asia                      8382
# Sub-Saharan Africa              4813
# Southeast Asia                  3311
# North America                   2873
# Eastern Europe                  1557
# East Asia                        630
# Name: Region, dtype: int64

# %%
terrorism_df['State'].value_counts().head(10)
# Out:
# Northern Ireland         3733
# Unknown                  3548
# Lima                     2605
# San Salvador             1923
# Antioquia                1699
# Santiago Metropolitan    1584
# Basque Country           1314
# Sindh                    1280
# Punjab                   1234
# Corsica                  1121
# Name: State, dtype: int64

# %%
terrorism_df['Target_subtype'].value_counts().head(10)
# Out:
# Military Unit/Patrol/Convoy                             4827
# Police Security Forces/Officers                         3993
# others                                                  3527
# Politician or Political Party Movement/Meeting/Rally    3429
# Electricity                                             3104
# Government Building/Facility/Office                     2923
# Bank/Commerce                                           2698
# Village/City/Town/Suburb                                2570
# Police Building (headquarters, station, school)         2461
# Unnamed Civilian/Unspecified                            2365
# Name: Target_subtype, dtype: int64

# %%
terrorism_df['City'].value_counts().head(10)
# Out:
# Unknown         4959
# Lima            2353
# Belfast         1892
# Santiago        1559
# San Salvador    1558
# Karachi         1150
# Bogota           882
# Istanbul         873
# Beirut           858
# Medellin         824
# Name: City, dtype: int64

# %%
terrorism_df['Attack_type'].value_counts().head(10)
# Out:
# Bombing/Explosion                      30841
# Armed Assault                          17115
# Assassination                          12556
# Facility/Infrastructure Attack          4908
# Hostage Taking (Kidnapping)             3353
# Unknown                                 2748
# Hostage Taking (Barricade Incident)      634
# Unarmed Assault                          451
# Hijacking                                362
# Name: Attack_type, dtype: int64

# %%
terrorism_df['Target_type'].value_counts().head(10)
# Out:
# Private Citizens & Property       13932
# Business                          12060
# Military                           9749
# Government (General)               9518
# Police                             8172
# Transportation                     3802
# Utilities                          3739
# Government (Diplomatic)            2360
# Journalists & Media                1612
# Religious Figures/Institutions     1483
# Name: Target_type, dtype: int64

# %%
terrorism_df['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             25644
# Shining Path (SL)                                    4506
# Farabundo Marti National Liberation Front (FMLN)     3351
# Irish Republican Army (IRA)                          2662
# Basque Fatherland and Freedom (ETA)                  1863
# Revolutionary Armed Forces of Colombia (FARC)        1339
# National Liberation Army of Colombia (ELN)           1219
# Palestinians                                         1110
# Liberation Tigers of Tamil Eelam (LTTE)              1087
# Kurdistan Workers' Party (PKK)                       1077
# Name: Gang_name, dtype: int64

# %%
terrorism_df['Weapon_type'].value_counts().head(10)
# Out:
# Explosives            31083
# Firearms              26925
# Unknown                6906
# Incendiary             6150
# Melee                  1614
# Chemical                127
# Other                    45
# Sabotage Equipment       43
# Vehicle                  30
# Fake Weapons             23
# Name: Weapon_type, dtype: int64

# %% [markdown]
# ***Visualize Data***

# %%
plt.figure(figsize=(20,5));
sns.countplot(x=terrorism_df.Weapon_type);

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year')
sns.countplot(x=terrorism_df.Year);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month')
sns.countplot(x=terrorism_df.Month);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Day')
sns.countplot(x=terrorism_df.Day);

# %%
plt.figure(figsize=(30,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country')
sns.countplot(x=terrorism_df.Country);

# %%
plt.figure(figsize=(28,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 0)
plt.title('Attacks by Region')
sns.countplot(x=terrorism_df.Region);

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 90)
plt.title('Based on Target type')
sns.countplot(x=terrorism_df.Target_type);

# %%
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':12});
plt.xticks(rotation = 0)
plt.title('Based on Attack type')
sns.countplot(x=terrorism_df.Attack_type);

# %% [markdown]
# ***Final Report **
#  Most of the attacks were through either Bombing or Explosion.
#  Most of the attacks were attacked through explosives and then through firearms.
# Attacks were more during 2014 and then in 2015. When compared to attacks from
# 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.
# Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st.
# Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
# The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
# For most of the attacks, the target is Private Citizens& property and the next Military leads.
